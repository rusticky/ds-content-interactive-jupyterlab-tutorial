# %% [markdown]
# ![rmotr](https://user-images.githubusercontent.com/7065401/52071918-bda15380-2562-11e9-828c-7f95297e4a82.png)
# <hr style="margin-bottom: 40px;">
#
# <img src="https://user-images.githubusercontent.com/7065401/58563302-42466a80-8201-11e9-9948-b3e9f88a5662.jpg"
#     style="width:400px; float: right; margin: 0 40px 40px 40px;"></img>
#
# # Exercises
# ## Bike store sales

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Hands on!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
sales = pd.read_csv('sample_data/sales_data.csv',
    parse_dates=['Date'])

# %%
sales.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013          19.0     Youth (<25)
# 1 2015-11-26   26  November  2015          19.0     Youth (<25)
# 2 2014-03-23   23     March  2014          49.0  Adults (35-64)
# 3 2016-03-23   23     March  2016          49.0  Adults (35-64)
# 4 2014-05-15   15       May  2014          47.0  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit    Cost  \
# 0  Hitch Rack - 4-Bike             8.0       45.0       120.0   590.0   360.0
# 1  Hitch Rack - 4-Bike             8.0       45.0       120.0   590.0   360.0
# 2  Hitch Rack - 4-Bike            23.0       45.0       120.0  1366.0  1035.0
# 3  Hitch Rack - 4-Bike            20.0       45.0       120.0  1188.0   900.0
# 4  Hitch Rack - 4-Bike             4.0       45.0       120.0   238.0   180.0
#
#    Revenue
# 0    950.0
# 1    950.0
# 2   2401.0
# 3   2088.0
# 4    418.0

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What's the mean of `Customers_Age`?

# %%
sales ['Customer_Age'].mean()
# Out:
# 35.87081600940742

# %% [markdown]
# Why don't you try with `.mean()`

# %% [markdown]
# Go ahead and show a <b>density (KDE)</b> and a <b>box plot</b> with the `Customer_Age` data:

# %%
sales['Customer_Age'].plot(kind='kde', figsize=(14,6))
# Out:
# <Axes: ylabel='Density'>

# %%
sales['Customer_Age'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <Axes: >

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What's the mean of `Order_Quantity`?

# %%
sales['Order_Quantity'].mean()
# Out:
# 14.904539918525051

# %% [markdown]
# Go ahead and show a <b>histogram</b> and a <b>box plot</b> with the `Order_Quantity` data:

# %%
# your code goes here
sales['Order_Quantity'].plot(kind='hist', bins=30, figsize=(14,6))
# Out:
# <Axes: ylabel='Frequency'>

# %%
sales['Order_Quantity'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <Axes: >

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales per year do we have?

# %%
# your code goes here
sales['Year'].value_counts()
# Out:
# Year
# 2014    6918
# 2016    6918
# 2013    4988
# 2015    4988
# Name: count, dtype: int64

# %% [markdown]
# Go ahead and show a <b>pie plot</b> with the previous data:

# %%
sales['Year'].value_counts().plot(kind='pie', figsize=(6,6))
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales per month do we have?

# %%
sales['Month'].value_counts()
# Out:
# Month
# June         2396
# December     2350
# May          2308
# April        2142
# March        2130
# February     2020
# January      1974
# October      1818
# August       1730
# November     1714
# September    1678
# July         1552
# Name: count, dtype: int64

# %% [markdown]
# Go ahead and show a <b>bar plot</b> with the previous data:

# %%
sales['Month'].value_counts().plot(kind='bar', figsize=(14,6))
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Which country has the most sales `quantity of sales`?

# %%
sales['Country'].value_counts().head(1)
# Out:
# Country
# United States    8713
# Name: count, dtype: int64

# %%
sales['Country'].value_counts()
# Out:
# Country
# United States     8713
# Australia         4768
# Canada            3092
# United Kingdom    2828
# Germany           2336
# France            2074
# Name: count, dtype: int64

# %%
sales['Country'].value_counts()
# Out:
# Country
# United States     8713
# Australia         4768
# Canada            3092
# United Kingdom    2828
# Germany           2336
# France            2074
# Name: count, dtype: int64

# %% [markdown]
# Go ahead and show a <b>bar plot</b> of the sales per country:

# %%
sales['Country'].value_counts().plot(kind='bar', figsize=(14,6))
# Out:
# <Axes: xlabel='Country'>

# %%
sales['Country'].value_counts().plot(kind='bar', figsize=(14,6))
# Out:
# <Axes: xlabel='Country'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Create a list of every product sold

# %%
sales['Product'].value_counts()
# Out:
# Product
# Water Bottle - 30 oz.     10794
# AWC Logo Cap               4358
# Road Bottle Cage           2640
# Mountain Bottle Cage       2444
# Bike Wash - Dissolver      1804
# Fender Set - Mountain       723
# Hitch Rack - 4-Bike         596
# All-Purpose Bike Stand      452
# Name: count, dtype: int64

# %%
#sales.loc[:, 'Product'].unique()

sales.loc[:, 'Product'].unique()
# Out:
# array(['Hitch Rack - 4-Bike', 'All-Purpose Bike Stand',
#        'Mountain Bottle Cage', 'Water Bottle - 30 oz.',
#        'Road Bottle Cage', 'AWC Logo Cap', 'Bike Wash - Dissolver',
#        'Fender Set - Mountain', nan], dtype=object)

# %% [markdown]
# Create a **bar plot** showing the 10 most sold products (best sellers):

# %%
sales['Product'].value_counts().head(10).plot(kind='bar', figsize=(14,6))
# Out:
# <Axes: xlabel='Product'>

# %%
sales['Product'].value_counts().head(10).plot(kind='bar', figsize=(14,6))
# Out:
# <Axes: xlabel='Product'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between `Unit_Cost` and `Unit_Price`?
#
# Show a <b>scatter plot</b> between both columns.

# %%
# your code goes here
sales.plot(kind='scatter', x='Unit_Cost', y='Unit_Price', figsize=(6,6))
# Out:
# <Axes: xlabel='Unit_Cost', ylabel='Unit_Price'>

# %%
sales.plot(kind='scatter', x='Unit_Cost', y='Unit_Price', figsize=(6,6))
# Out:
# <Axes: xlabel='Unit_Cost', ylabel='Unit_Price'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between `Order_Quantity` and `Profit`?
#
# Show a <b>scatter plot</b> between both columns.

# %%
sales.plot(kind='scatter', x="Order_Quantity", y="Profit", figsize=(6,6))
# Out:
# <Axes: xlabel='Order_Quantity', ylabel='Profit'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between `Profit` per `Country`?
#
# Show a grouped <b>box plot</b> per country with the profit values.

# %%
sales[['Profit', 'Country']].boxplot(by='Country', figsize=(10,6))
# Out:
# <Axes: title={'center': 'Profit'}, xlabel='[Country]'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add and calculate a new `Calculated_Date` column
#
# Use `Day`, `Month`, `Year` to create a `Date` column (`YYYY-MM-DD`).

# %%
sales['Calculated_Date']=sales[['Year', 'Month', 'Day']].apply(lambda x: '{}-{}-{}'.format(x[0], x[1],x[2]), axis=1)
# Out:
# <ipython-input-113-b77360222d34>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sales['Calculated_Date']=sales[['Year', 'Month', 'Day']].apply(lambda x: '{}-{}-{}'.format(x[0], x[1],x[2]), axis=1)

# %%
sales['Calculated_Date'].head()
# Out:
# 0    2013-November-26
# 1    2015-November-26
# 2       2014-March-23
# 3       2016-March-23
# 4         2014-May-15
# Name: Calculated_Date, dtype: object

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Parse your `Calculated_Date` column into a datetime object

# %%
# your code goes here
sales['Calculated_Date']=pd.to_datetime(sales['Calculated_Date'])

# %%
sales['Calculated_Date'].head()
# Out:
# 0   2013-11-26
# 1   2015-11-26
# 2   2014-03-23
# 3   2016-03-23
# 4   2014-05-15
# Name: Calculated_Date, dtype: datetime64[ns]

# %%
sales.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013          19.0     Youth (<25)
# 1 2015-11-26   26  November  2015          19.0     Youth (<25)
# 2 2014-03-23   23     March  2014          49.0  Adults (35-64)
# 3 2016-03-23   23     March  2016          49.0  Adults (35-64)
# 4 2014-05-15   15       May  2014          47.0  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit    Cost  \
# 0  Hitch Rack - 4-Bike             8.0       45.0       120.0   590.0   360.0
# 1  Hitch Rack - 4-Bike             8.0       45.0       120.0   590.0   360.0
# 2  Hitch Rack - 4-Bike            23.0       45.0       120.0  1366.0  1035.0
# 3  Hitch Rack - 4-Bike            20.0       45.0       120.0  1188.0   900.0
# 4  Hitch Rack - 4-Bike             4.0       45.0       120.0   238.0   180.0
#
#    Revenue Calculated_Date
# 0    950.0      2013-11-26
# 1    950.0      2015-11-26
# 2   2401.0      2014-03-23
# 3   2088.0      2016-03-23
# 4    418.0      2014-05-15

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How did sales evolve through the years?
#
# Show a <b>line plot</b> using `Calculated_Date` column as the x-axis and the count of sales as the y-axis.

# %%
sales['Calculated_Date'].value_counts().plot(kind='line', figsize=(14,6))
# Out:
# <Axes: xlabel='Calculated_Date'>

# %%
sales['Calculated_Date'].value_counts().plot(kind='line', figsize=(14,6))
# Out:
# <Axes: xlabel='Calculated_Date'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Increase 50 U$S revenue to every sale

# %%
sales['Revenue']= sales['Revenue'] +50

# %%
#sales['Revenue'] = sales['Revenue'] + 50

sales['Revenue'] += 50

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made in `Canada` or `France`?

# %%
sales.loc[(sales['Country']=='Canada') | (sales['Country']=='France')].shape[0]
# Out:
# 5166

# %%
sales.loc[(sales['Country'] == 'Canada') | (sales['Country'] == 'France')].shape[0]
# Out:
# 5166

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many `Bike Racks` orders were made from Canada?

# %%
sales.loc[(sales['Country']=='Canada')& (sales['Sub_Category']=='Bike Racks')].shape[0]
# Out:
# 104

# %%
sales.loc[(sales['Country'] == 'Canada') & (sales['Sub_Category'] == 'Bike Racks')].shape[0]
# Out:
# 104

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made in each region (state) of France?

# %%
sales.loc[sales['Country']=='France','State'].value_counts()
# Out:
# State
# Seine (Paris)        424
# Seine Saint Denis    316
# Nord                 280
# Hauts de Seine       224
# Essonne              208
# Yveline              168
# Loiret                78
# Moselle               70
# Seine et Marne        68
# Val de Marne          42
# Charente-Maritime     38
# Loir et Cher          36
# Val d'Oise            36
# Garonne (Haute)       34
# Somme                 34
# Pas de Calais         18
# Name: count, dtype: int64

# %%
france_states = sales.loc[sales['Country'] == 'France', 'State'].value_counts()

france_states
# Out:
# State
# Seine (Paris)        424
# Seine Saint Denis    316
# Nord                 280
# Hauts de Seine       224
# Essonne              208
# Yveline              168
# Loiret                78
# Moselle               70
# Seine et Marne        68
# Val de Marne          42
# Charente-Maritime     38
# Loir et Cher          36
# Val d'Oise            36
# Garonne (Haute)       34
# Somme                 34
# Pas de Calais         18
# Name: count, dtype: int64

# %% [markdown]
# Go ahead and show a <b>bar plot</b> with the results:

# %%
sales.loc[sales['Country'] == 'France', 'State'].value_counts().plot(kind='bar', figsize=(14,6))
# Out:
# <Axes: xlabel='State'>

# %%
france_states.plot(kind='bar', figsize=(14,6))
# Out:
# <Axes: xlabel='State'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales were made per category?

# %%
sales['Product_Category'].describe()
# Out:
# count           23811
# unique              2
# top       Accessories
# freq            19453
# Name: Product_Category, dtype: object

# %%
sales['Product_Category'].value_counts()
# Out:
# Product_Category
# Accessories    19453
# Clothing        4358
# Name: count, dtype: int64

# %% [markdown]
# Go ahead and show a <b>pie plot</b> with the results:

# %%
sales['Product_Category'].value_counts().plot(kind='pie', figsize=(14,6))
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made per accessory sub-categories?

# %%
sales.loc[sales['Product_Category'] == 'Accessories', 'Sub_Category'].value_counts()
# Out:
# Sub_Category
# Bottles and Cages    15876
# Cleaners              1802
# Fenders                727
# Bike Racks             592
# Bike Stands            456
# Name: count, dtype: int64

# %%
accessories = sales.loc[sales['Product_Category'] == 'Accessories', 'Sub_Category'].value_counts()

accessories
# Out:
# Sub_Category
# Bottles and Cages    15876
# Cleaners              1802
# Fenders                727
# Bike Racks             592
# Bike Stands            456
# Name: count, dtype: int64

# %% [markdown]
# Go ahead and show a <b>bar plot</b> with the results:

# %%
accessories.plot(kind='bar', figsize =(14,6))
# Out:
# <Axes: xlabel='Sub_Category'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made per bike sub-categories?

# %%
sales.loc[sales['Product_Category']=='Bikes', 'Sub_Category'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
bikes = sales.loc[sales['Product_Category'] == 'Bikes', 'Sub_Category'].value_counts()
bikes
# Out:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# Go ahead and show a <b>pie plot</b> with the results:

# %%
bikes.plot(kind='pie', figsize=(14,6))
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Which gender has the most amount of sales?

# %%
sales.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013          19.0     Youth (<25)
# 1 2015-11-26   26  November  2015          19.0     Youth (<25)
# 2 2014-03-23   23     March  2014          49.0  Adults (35-64)
# 3 2016-03-23   23     March  2016          49.0  Adults (35-64)
# 4 2014-05-15   15       May  2014          47.0  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit    Cost  \
# 0  Hitch Rack - 4-Bike             8.0       45.0       120.0   590.0   360.0
# 1  Hitch Rack - 4-Bike             8.0       45.0       120.0   590.0   360.0
# 2  Hitch Rack - 4-Bike            23.0       45.0       120.0  1366.0  1035.0
# 3  Hitch Rack - 4-Bike            20.0       45.0       120.0  1188.0   900.0
# 4  Hitch Rack - 4-Bike             4.0       45.0       120.0   238.0   180.0
#
#    Revenue Calculated_Date
# 0   1050.0      2013-11-26
# 1   1050.0      2015-11-26
# 2   2501.0      2014-03-23
# 3   2188.0      2016-03-23
# 4    518.0      2014-05-15

# %%
sales['Customer_Gender'].value_counts()
# Out:
# Customer_Gender
# M    12183
# F    11628
# Name: count, dtype: int64

# %%
sales['Customer_Gender'].value_counts().plot(kind='bar', figsize=(14,6))
# Out:
# <Axes: xlabel='Customer_Gender'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales with more than 500 in `Revenue` were made by men?

# %%
sales.loc[(sales['Customer_Gender']== 'M') & (sales['Revenue']>500)].shape[0]
# Out:
# 571

# %%
sales.loc[(sales['Customer_Gender'] == 'M') & (sales['Revenue'] == 500)].shape[0]
# Out:
# 3

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Get the top-5 sales with the highest revenue

# %%
sales.sort_values(['Revenue'], ascending=False).head(5)
# Out:
#           Date  Day     Month  Year  Customer_Age             Age_Group  \
# 245 2016-01-07    7   January  2016          31.0  Young Adults (25-34)
# 90  2014-02-12   12  February  2014          46.0        Adults (35-64)
# 182 2014-01-17   17   January  2014          53.0        Adults (35-64)
# 244 2014-01-07    7   January  2014          31.0  Young Adults (25-34)
# 183 2016-01-17   17   January  2016          53.0        Adults (35-64)
#
#     Customer_Gender        Country             State Product_Category  \
# 245               M         Canada  British Columbia      Accessories
# 90                M  United States        California      Accessories
# 182               F  United States        California      Accessories
# 244               M         Canada  British Columbia      Accessories
# 183               F  United States        California      Accessories
#
#     Sub_Category              Product  Order_Quantity  Unit_Cost  Unit_Price  \
# 245   Bike Racks  Hitch Rack - 4-Bike            30.0       45.0       120.0
# 90    Bike Racks  Hitch Rack - 4-Bike            30.0       45.0       120.0
# 182   Bike Racks  Hitch Rack - 4-Bike            30.0       45.0       120.0
# 244   Bike Racks  Hitch Rack - 4-Bike            29.0       45.0       120.0
# 183   Bike Racks  Hitch Rack - 4-Bike            29.0       45.0       120.0
#
#      Profit    Cost  Revenue Calculated_Date
# 245  2214.0  1350.0   3664.0      2016-01-07
# 90   2178.0  1350.0   3628.0      2014-02-12
# 182  2178.0  1350.0   3628.0      2014-01-17
# 244  2140.0  1305.0   3545.0      2014-01-07
# 183  2105.0  1305.0   3510.0      2016-01-17

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Get the sale with the highest revenue

# %%
sales.sort_values(['Revenue'], ascending=False).head(1)
# Out:
#           Date  Day    Month  Year  Customer_Age             Age_Group  \
# 245 2016-01-07    7  January  2016          31.0  Young Adults (25-34)
#
#     Customer_Gender Country             State Product_Category Sub_Category  \
# 245               M  Canada  British Columbia      Accessories   Bike Racks
#
#                  Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  \
# 245  Hitch Rack - 4-Bike            30.0       45.0       120.0  2214.0
#
#        Cost  Revenue Calculated_Date
# 245  1350.0   3664.0      2016-01-07

# %%
cond = sales['Revenue'] == sales['Revenue'].max()

# %%
#sales.sort_values(['Revenue'], ascending=False).head(1)

cond = sales['Revenue'] == sales['Revenue'].max()

sales.loc[cond]
# Out:
#           Date  Day    Month  Year  Customer_Age             Age_Group  \
# 245 2016-01-07    7  January  2016          31.0  Young Adults (25-34)
#
#     Customer_Gender Country             State Product_Category Sub_Category  \
# 245               M  Canada  British Columbia      Accessories   Bike Racks
#
#                  Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  \
# 245  Hitch Rack - 4-Bike            30.0       45.0       120.0  2214.0
#
#        Cost  Revenue Calculated_Date
# 245  1350.0   3664.0      2016-01-07

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What is the mean `Order_Quantity` of orders with more than 10K in revenue?

# %%
cond = sales['Revenue'] > 10_000

sales.loc[cond, 'Order_Quantity'].mean()
# Out:
# nan

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What is the mean `Order_Quantity` of orders with less than 10K in revenue?

# %%
condi = sales['Revenue']<10_000

# %%
sales.loc[condi, 'Order_Quantity'].mean()
# Out:
# 14.904539918525051

# %%
cond = sales['Revenue'] < 10_000

sales.loc[cond, 'Order_Quantity'].mean()
# Out:
# 14.904539918525051

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made in May of 2016?

# %%
may2016= (sales['Year']== 2016) & (sales['Month']== 'May')

# %%
sales.loc[may2016].shape[0]
# Out:
# 1154

# %%
cond = (sales['Year'] == 2016) & (sales['Month'] == 'May')

sales.loc[cond].shape[0]
# Out:
# 1154

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made between May and July of 2016?

# %%
mj2016 = (sales['Year']== 2016) & (sales['Month'].isin(['May', 'June', 'July']))

# %%
sales.loc[mj2016].shape[0]
# Out:
# 2785

# %%
cond = (sales['Year'] == 2016) & (sales['Month'].isin(['May', 'June', 'July']))

sales.loc[cond].shape[0]
# Out:
# 2785

# %% [markdown]
# Show a grouped <b>box plot</b> per month with the profit values.

# %%
profit_2016 = sales.loc[sales['Year'] == 2016, ['Profit', 'Month']]
profit_2016.boxplot(by='Month', figsize=(14,6))
# Out:
# <Axes: title={'center': 'Profit'}, xlabel='[Month]'>

# %%
profit_2016 = sales.loc[sales['Year'] == 2016, ['Profit', 'Month']]

profit_2016.boxplot(by='Month', figsize=(14,6))
# Out:
# <Axes: title={'center': 'Profit'}, xlabel='[Month]'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add 7.2% TAX on every sale `Unit_Price` within United States

# %%
sales.loc[sales['Country']== 'United States', 'Unit_Price'] *=1.072

# %%
#sales.loc[sales['Country'] == 'United States', 'Unit_Price'] = sales.loc[sales['Country'] == 'United States', 'Unit_Price'] * 1.072

sales.loc[sales['Country'] == 'United States', 'Unit_Price'] *= 1.072

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
